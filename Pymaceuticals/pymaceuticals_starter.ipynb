# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Observation 1: Tumor Volume: It varies widely across different drug regimens. For example, "Infubinol" shows tumor volumes in the 60s (e.g., 67.97, 65.52), suggesting moderate control of tumor size. "Ramicane" and "Capomulin" seem to have lower tumor volumes (e.g., 38.41, 30.63), potentially indicating better efficacy. Next step would be to compare average tumor volumes for each drug regimen to identify the most effective treatment. Also, evaluate the correlation between metastatic sites and tumor volume.
#
# ### Observation 2: Efficiency of the drugs vary, drugs like Ketapril (55.24 mm³), Naftisol (54.33 mm³), and Stelasyn (54.23 mm³) have higher tumor volumes, making them less effective. Ketapril shows the highest variance (68.55) and standard deviation (8.28), suggesting highly variable outcomes and less reliability. Further research and potential treatment trials should be done on Capomulin and Ramicane, as their results are both effective and consistent.
#
# ### Observation 3: Lighter mice seem to have lower tumor volumes, (e.g., lighter weights like f966 and u364 with 17 g and heavier weights like b879 (26g) and x773 (30g)). Weight might play a role in tumor volume variability, which could provide insights into treatment optimization.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import seaborn as sns

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combine_df = pd.merge(study_results, mouse_metadata, how = "left", on = "Mouse ID")

# Display the data table for preview
combine_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
len(combine_df["Mouse ID"].unique())
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicate_mice = combine_df.loc[combine_df.duplicated(subset = ["Mouse ID", "Timepoint"]), "Mouse ID"].unique()
duplicate_mice
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
duplicate_mice_df = combine_df.loc[combine_df["Mouse ID"] == "g989"]
duplicate_mice_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# 1380     g989         30           59.082294                 1     Propriva
# 1592     g989         35           62.570880                 2     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# 329   Female          21          26
# 360   Female          21          26
# 620   Female          21          26
# 681   Female          21          26
# 815   Female          21          26
# 869   Female          21          26
# 950   Female          21          26
# 1111  Female          21          26
# 1195  Female          21          26
# 1380  Female          21          26
# 1592  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_combine_df = combine_df[combine_df['Mouse ID'].isin(duplicate_mice) == False]
clean_combine_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1       Male          15          29
# 2     Female           2          29
# 3     Female          11          30
# 4       Male          21          25
# ...      ...         ...         ...
# 1888    Male          12          25
# 1889    Male          18          17
# 1890  Female          11          26
# 1891  Female          21          30
# 1892  Female           4          26
#
# [1880 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
len(clean_combine_df["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
means = clean_combine_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean()
medians = clean_combine_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].median()
variances = clean_combine_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].var()
stand_dev = clean_combine_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].std()
sems = clean_combine_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].sem()

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume.
# Assemble the resulting series into a single summary DataFrame.
summary_table = pd.DataFrame({"Mean of Tumor Volume": means,
                             "Medians of Tumor Volume": medians,
                             "Variances of Tumor Volume": variances,
                             "Standard Deviation of Tumor Volume": stand_dev,
                             "SEM of Tumor Volume": sems
                             })
summary_table
# Out:
#               Mean of Tumor Volume  Medians of Tumor Volume  \
# Drug Regimen
# Capomulin                40.675741                41.557809
# Ceftamin                 52.591172                51.776157
# Infubinol                52.884795                51.820584
# Ketapril                 55.235638                53.698743
# Naftisol                 54.331565                52.509285
# Placebo                  54.033581                52.288934
# Propriva                 52.320930                50.446266
# Ramicane                 40.216745                40.673236
# Stelasyn                 54.233149                52.431737
# Zoniferol                53.236507                51.818479
#
#               Variances of Tumor Volume  Standard Deviation of Tumor Volume  \
# Drug Regimen
# Capomulin                     24.947764                            4.994774
# Ceftamin                      39.290177                            6.268188
# Infubinol                     43.128684                            6.567243
# Ketapril                      68.553577                            8.279709
# Naftisol                      66.173479                            8.134708
# Placebo                       61.168083                            7.821003
# Propriva                      43.852013                            6.622085
# Ramicane                      23.486704                            4.846308
# Stelasyn                      59.450562                            7.710419
# Zoniferol                     48.533355                            6.966589
#
#               SEM of Tumor Volume
# Drug Regimen
# Capomulin                0.329346
# Ceftamin                 0.469821
# Infubinol                0.492236
# Ketapril                 0.603860
# Naftisol                 0.596466
# Placebo                  0.581331
# Propriva                 0.544332
# Ramicane                 0.320955
# Stelasyn                 0.573111
# Zoniferol                0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
summary_table = clean_combine_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":["mean","median","var","std","sem"]})
summary_table
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
clean_combine_df.groupby("Drug Regimen").size().sort_values(ascending=False).plot(kind="bar", title="Drug Regimen Size", ylabel="Count", color="purple")
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
# Data Visualization 

data = clean_combine_df.groupby("Drug Regimen").size().sort_values(ascending=False)

# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.bar(data.index, data.values, color="firebrick", align="center")

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Drug Regimen", fontfamily="Arial", fontsize=12)
plt.ylabel("Count", fontfamily="Arial", fontsize=12)
plt.title("Mouse/Timepoints per Drug Regimen", fontweight="bold", fontsize=16, fontfamily="Arial")

# Set X/Y Limits
# plt.ylim(0, 350)

# Add in a background grid
plt.grid(axis="y", linestyle="--", color="lightgrey", alpha=0.75)

# Show/Save the Graph
plt.show()

# %%
#Mouse Data
option1 = clean_combine_df[["Mouse ID", "Sex"]].drop_duplicates()
option1.shape
# Out:
# (248, 2)

# %%
option1.Sex.value_counts()
# Out:
# Sex
# Male      125
# Female    123
# Name: count, dtype: int64

# %%
125/248
# Out:
# 0.5040322580645161

# %%
# Generate a pie chart, using Pandas, showing the distribution of unique female versus male mice used in the study

# Get the unique mice with their gender
data = option1.Sex.value_counts()

# Make the pie chart
data.plot(kind="pie", title="Mouse Genders", autopct="%1.1f%%")
plt.show()

# %%
# Generate a pie chart, using pyplot, showing the distribution of unique female versus male mice used in the study

# Get the unique mice with their gender

# Make the pie chart
# Data Visualization Code
data = option1.Sex.value_counts()

# Change Canvas Size
plt.figure(figsize=(6, 6))

# Create a basic plot
plt.pie(data.values, labels=data.index, colors=["teal", "lavender"], autopct="%1.1f%%", shadow=False, startangle=180, pctdistance=0.85)

# Customizations
# DONUT
centre_circle = plt.Circle((0,0), 0.70, fc='white')  # Adjust 0.70 for hole size
plt.gca().add_artist(centre_circle)

# Change colors
# Add in reference lines
# Add Labels/Title
plt.title(f"% of Gender by Mouse in Study\n", fontweight="bold", fontsize=16, fontfamily="Arial")

# Set X/Y Limits
plt.axis("equal")

# Show/Save the Graph
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_time = clean_combine_df.groupby("Mouse ID").Timepoint.max().reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
merged_combine_df = pd.merge(max_time, clean_combine_df, on=["Mouse ID", "Timepoint"], how="left")

drugs = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
mask = merged_combine_df["Drug Regimen"].isin(drugs)
merged_combine_df = merged_combine_df.loc[mask].reset_index(drop=True)
merged_combine_df
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      a203         45           67.973419                 2    Infubinol
# 1      a251         45           65.525743                 1    Infubinol
# 2      a275         45           62.999356                 3     Ceftamin
# 3      a411         45           38.407618                 1     Ramicane
# 4      a444         45           43.047543                 0     Ramicane
# ..      ...        ...                 ...               ...          ...
# 95     y769         45           68.594745                 4     Ceftamin
# 96     y793         45           31.896238                 2    Capomulin
# 97     y865         45           64.729837                 3     Ceftamin
# 98     z578         45           30.638696                 0     Ramicane
# 99     z581         45           62.754451                 3    Infubinol
#
#        Sex  Age_months  Weight (g)
# 0   Female          20          23
# 1   Female          21          25
# 2   Female          20          28
# 3     Male           3          22
# 4   Female          10          25
# ..     ...         ...         ...
# 95  Female           6          27
# 96    Male          17          17
# 97    Male          23          26
# 98    Male          11          16
# 99  Female          24          25
#
# [100 rows x 8 columns]

# %%
plt.figure(figsize=(12, 6))

# Create a basic plot
sns.boxplot(data= merged_combine_df, y="Tumor Volume (mm3)", x="Drug Regimen", color="magenta")

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Drug Regimen", fontfamily="Arial", fontsize=12)
plt.ylabel("Tumor Volume (mm3)", fontfamily="Arial", fontsize=12)
plt.title("Tumor Volume by Drug", fontweight="bold", fontsize=16, fontfamily="Arial")

# Add in a background grid
plt.grid(axis="y", linestyle="--", color="lightgrey", alpha=0.75)
# plt.xlim(0,20)

# Show/Save the Graph
plt.show()

# %%
# Put treatments into a list for for loop (and later for plot labels)

treatments = merged_combine_df['Drug Regimen'].unique()

# Create empty list to fill with tumor vol data (for plotting)
tumor_volumes = []

# Calculate the IQR and quantitatively determine if there are any potential outliers.
# Iterate through each treatment
for treatment in treatments:
    # Locate the rows which contain mice on each drug and get the tumor volumes
    treatment_data = merged_combine_df.loc[merged_combine_df['Drug Regimen'] == treatment, 'Tumor Volume (mm3)']

    # add subset
    tumor_volumes.append(treatment_data)
    
    # Calculate IQR for outlier detection
    q1 = np.percentile(treatment_data, 25)
    q3 = np.percentile(treatment_data, 75)
    iqr = q3 - q1
    
    # Determine outliers using upper and lower bounds
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    
    # Identify outliers
    outliers = treatment_data[(treatment_data < lower_bound) | (treatment_data > upper_bound)]
    print(f"Outliers for {treatment}: {outliers.tolist()}")
# Out:
# Outliers for Infubinol: [36.3213458]
# Outliers for Ceftamin: []
# Outliers for Ramicane: []
# Outliers for Capomulin: []

# %%
tumor_volumes
# Out:
# [0     67.973419
#  1     65.525743
#  6     57.031862
#  8     66.083066
#  14    72.226731
#  15    36.321346
#  18    60.969711
#  20    62.435404
#  22    60.918767
#  31    67.289621
#  41    66.196912
#  42    62.117279
#  52    47.010364
#  55    60.165180
#  57    55.629428
#  58    45.699331
#  60    54.656549
#  69    55.650681
#  79    46.250112
#  80    54.048608
#  81    51.542431
#  85    50.005138
#  86    58.268442
#  93    67.685569
#  99    62.754451
#  Name: Tumor Volume (mm3), dtype: float64,
#  2     62.999356
#  10    45.000000
#  11    56.057749
#  13    55.742829
#  23    48.722078
#  28    47.784682
#  36    61.849023
#  39    68.923185
#  43    67.748662
#  44    57.918381
#  46    46.784535
#  47    59.851956
#  48    64.299830
#  56    59.741901
#  59    61.433892
#  61    64.192341
#  74    45.000000
#  75    52.925348
#  76    45.000000
#  84    67.527482
#  89    45.000000
#  91    64.634949
#  92    61.386660
#  95    68.594745
#  97    64.729837
#  Name: Tumor Volume (mm3), dtype: float64,
#  3     38.407618
#  4     43.047543
#  5     38.810366
#  7     32.978522
#  16    38.342008
#  17    33.397653
#  19    37.311236
#  21    40.659006
#  27    29.128472
#  29    33.562402
#  30    36.374510
#  37    31.560470
#  38    36.134852
#  40    22.050126
#  50    30.564625
#  54    31.095335
#  62    45.220869
#  63    36.561652
#  66    37.225650
#  67    43.419381
#  71    30.276232
#  77    40.667713
#  87    43.166373
#  94    44.183451
#  98    30.638696
#  Name: Tumor Volume (mm3), dtype: float64,
#  9     38.982878
#  12    38.939633
#  24    30.485985
#  25    37.074024
#  26    40.159220
#  32    47.685963
#  33    37.311846
#  34    38.125164
#  35    38.753265
#  45    41.483008
#  49    38.846876
#  51    28.430964
#  53    33.329098
#  64    46.539206
#  65    32.377357
#  68    41.581521
#  70    23.343598
#  72    40.728578
#  73    34.455298
#  78    31.023923
#  82    40.658124
#  83    39.952347
#  88    36.041047
#  90    28.484033
#  96    31.896238
#  Name: Tumor Volume (mm3), dtype: float64]

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.
# Change Canvas Size
plt.figure(figsize=(12, 6))

plt.boxplot(tumor_volumes, tick_labels=treatments)

# Add Labels/Title
plt.xlabel("Drug Regimen", fontfamily="Arial", fontsize=12)
plt.ylabel("Tumor Volume (mm3)", fontfamily="Arial", fontsize=12)
plt.title("Tumor Volume by Drug", fontweight="bold", fontsize=16, fontfamily="Arial")

# Add in a background grid
plt.grid(axis="y", linestyle="--", color="pink", alpha=0.75)
# plt.xlim(0,20)

# Show/Save the Graph
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
mouse = "l509"

single_mouse_df = clean_combine_df.loc[clean_combine_df["Mouse ID"] == mouse].sort_values(by="Timepoint", ascending=True)

# single_mouse_df.plot(kind="line", x="Timepoint", y="Tumor Volume (mm3)")

# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.plot(single_mouse_df.Timepoint, single_mouse_df["Tumor Volume (mm3)"], color="yellow", linewidth=5)

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Timepoint (days)", fontfamily="Arial", fontsize=12)
plt.ylabel("Tumor Volume (mm3)", fontfamily="Arial", fontsize=12)
plt.title(f"Capomulin Treatment of Mouse: {mouse}", fontweight="bold", fontsize=16, fontfamily="Arial")

# # Set X/Y Limits
# plt.ylim(0, 90)
# plt.xlim(-2, 75)

# Add in a background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.75)

# Show/Save the Graph
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
regimen = "Capomulin"
capomulin_df = clean_combine_df.loc[clean_combine_df["Drug Regimen"] == regimen]
entire_capomulin_df = capomulin_df.groupby("Mouse ID").agg({"Tumor Volume (mm3)": "mean", "Weight (g)": "mean"}).reset_index()
entire_capomulin_df.head()
# Out:
#   Mouse ID  Tumor Volume (mm3)  Weight (g)
# 0     b128           41.963636        22.0
# 1     b742           40.083699        21.0
# 2     f966           36.505973        17.0
# 3     g288           41.990097        19.0
# 4     g316           44.613344        22.0

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.scatter(entire_capomulin_df["Weight (g)"], entire_capomulin_df["Tumor Volume (mm3)"], color="teal", edgecolor="white", s=200)

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Weight (g)", fontfamily="Arial", fontsize=12)
plt.ylabel("Tumor Volume (mm3)", fontfamily="Arial", fontsize=12)
plt.title("Weight (g) vs Tumor Volume (mm3)", fontweight="bold", fontsize=16, fontfamily="Arial")

# # Set X/Y Limits
# plt.ylim(0, 90)
# plt.xlim(-2, 75)

# Add in a background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.75)

# Show/Save the Graph
plt.show()
